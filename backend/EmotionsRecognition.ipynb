# %% [markdown]
# # Emotion classification using the RAVDESS dataset

# %% [markdown]
# The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS) is licensed under CC BY-NA-SC 4.0. and can be downloaded free of charge at https://zenodo.org/record/1188976.
#
# ***Construction and Validation***
#
# Construction and validation of the RAVDESS is described in our paper: Livingstone SR, Russo FA (2018) The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS): A dynamic, multimodal set of facial and vocal expressions in North American English. PLoS ONE 13(5): e0196391. https://doi.org/10.1371/journal.pone.0196391.
#
# The RAVDESS contains 7356 files. Each file was rated 10 times on emotional validity, intensity, and genuineness. Ratings were provided by 247 individuals who were characteristic of untrained adult research participants from North America. A further set of 72 participants provided test-retest data. High levels of emotional validity, interrater reliability, and test-retest intrarater reliability were reported. Validation data is open-access, and can be downloaded along with our paper from PLOS ONE.
#
# ***Description***
#
# The dataset contains the complete set of 7356 RAVDESS files (total size: 24.8 GB). Each of the 24 actors consists of three modality formats: Audio-only (16bit, 48kHz .wav), Audio-Video (720p H.264, AAC 48kHz, .mp4), and Video-only (no sound).  Note, there are no song files for Actor_18.
#
# ***Data***
#
# For this task, I have used 4948 samples from the RAVDESS dataset.
#
# The samples comes from:
#
# - Audio-only files;
# - Video + audio files: I have extracted the audio from each file using the script Mp4ToWav.py that you can find in the main directory of the project.
#
# ***License information***
#
# The RAVDESS is released under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License, CC BY-NA-SC 4.0
#
# ***File naming convention***
#
# Each of the 7356 RAVDESS files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 02-01-06-01-02-01-12.mp4). These identifiers define the stimulus characteristics:
#
# ***Filename identifiers***
#
# - Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# - Vocal channel (01 = speech, 02 = song).
# - Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# - Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the ‘neutral’ emotion.
# - Statement (01 = “Kids are talking by the door”, 02 = “Dogs are sitting by the door”).
# - Repetition (01 = 1st repetition, 02 = 2nd repetition).
# - Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 02-01-06-01-02-01-12.mp4
#
# - Video-only (02)
# - Speech (01)
# - Fearful (06)
# - Normal intensity (01)
# - Statement “dogs” (02)
# - 1st Repetition (01)
# - 12th Actor (12)
# - Female, as the actor ID number is even.

# %% [markdown]
# # Analysis
#
# We are using Colab, a Google Cloud environment for jupyter, so we need to import our files from Google Drive and then install LibROSA, a python package for music and audio analysis.
#
# After the import, we will plot the signal of the first file.

# %%
# !pip install librosa pandas tensorflow scikit-learn matplotlib
# Out:
# Requirement already satisfied: librosa in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.11.0)
# Requirement already satisfied: pandas in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.3)
# Requirement already satisfied: tensorflow in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.20.0)
# Requirement already satisfied: scikit-learn in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.3)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.64.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.16.3)
# Requirement already satisfied: joblib>=1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: cffi>=1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\ramya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import glob
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
from tensorflow import keras
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix

# %%
data, sampling_rate = librosa.load('./train_data/Actor_01/03-01-01-01-01-01-01.wav')

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)

# %% [markdown]
# # Load all files
#
# We will create our numpy array extracting Mel-frequency cepstral coefficients (MFCCs), while the classes to predict will be extracted from the name of the file (see the introductory section of this notebook to see the naming convention of the files of this dataset).

# %%
path = './train_data/Actor_01'
lst = []

for subdir, dirs, files in os.walk(path):
  for file in files:
      try:
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(os.path.join(subdir, file))
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        file = file[6:8]
        arr = mfccs, file
        lst.append(arr)
      # If the file is not valid, skip it
      except ValueError:
        continue

# %%
# Creating X and y: zip makes a list of all the first elements, and a list of all the second elements.
X, y = zip(*lst)

# %%
import numpy as np
X = np.asarray(X)
y = np.asarray(y)


X.shape, y.shape
# Out:
# ((60, 40), (60,))

# %% [markdown]
# # Decision Tree Classifier
#
# To make a first attempt in accomplishing this classification task I chose a decision tree:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %% [markdown]
# Let's go with our classification report.
#
# Before we start, a quick reminder of the classes we are trying to predict:
#
# emotions = {
#     "neutral": "01",
#     "calm": "02",
#     "happy": "03",
#     "sad": "04",
#     "angry": "05",
#     "fearful": "06",
#     "disgust": "07",
#     "surprised": "08"
# }

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.50      0.50         2
#            2       1.00      0.75      0.86         4
#            3       1.00      0.33      0.50         3
#            4       0.00      0.00      0.00         0
#            5       1.00      0.50      0.67         2
#            6       0.50      1.00      0.67         2
#            7       1.00      0.75      0.86         4
#            8       0.75      1.00      0.86         3
#
#     accuracy                           0.70        20
#    macro avg       0.72      0.60      0.61        20
# weighted avg       0.86      0.70      0.73        20
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Random Forest

# %% [markdown]
# In this second approach, I switched to a random forest classifier and I made a gridsearch to make some hyperparameters tuning.
#
# The gridsearch is not shown in the code below otherwise the notebook will require too much time to run.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rforest = RandomForestClassifier(criterion="gini", max_depth=10, max_features="log2", 
                                 max_leaf_nodes = 100, min_samples_leaf = 3, min_samples_split = 20, 
                                 n_estimators= 22000, random_state= 5)

# %%
rforest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features='log2', max_leaf_nodes=100,
#                        min_samples_leaf=3, min_samples_split=20,
#                        n_estimators=22000, random_state=5)

# %%
predictions = rforest.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         4
#            3       1.00      0.33      0.50         3
#            4       0.00      0.00      0.00         0
#            5       0.33      1.00      0.50         2
#            6       1.00      0.50      0.67         2
#            7       0.00      0.00      0.00         4
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.20        20
#    macro avg       0.29      0.23      0.21        20
# weighted avg       0.28      0.20      0.19        20
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Neural network

# %% [markdown]
# Let's build our neural network!
#
# To do so, we need to expand the dimensions of our array, adding a third one using the numpy "expand_dims" feature.

# %%
x_traincnn = np.expand_dims(X_train, axis=2)
x_testcnn = np.expand_dims(X_test, axis=2)

# %%
x_traincnn.shape, x_testcnn.shape
# Out:
# ((40, 40, 1), (20, 40, 1))

# %%
model = Sequential()
model.add(Conv1D(128, 5,padding='same',
                 input_shape=(40,1)))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128, 5,padding='same',))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.RMSprop(learning_rate=0.00005, rho=0.9)
# Out:
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# With *model.summary* we can see a recap of what we have build:

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 40, 128)        │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 5, 128)         │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         6,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,226 (348.54 KB)
#  Trainable params: 89,226 (348.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now we can compile and fit our model:

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
print(x_traincnn.dtype, y_train.dtype)
# Out:
# float32 int32

# %%
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=1000, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.1250 - loss: 28.7900WARNING:tensorflow:5 out of the last 5003 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x00000297813B2840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5003 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x00000297813B2840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.1000 - loss: 23.2023 - val_accuracy: 0.1500 - val_loss: 15.3460
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1250 - loss: 13.9925 - val_accuracy: 0.1500 - val_loss: 10.2131
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1000 - loss: 11.1356 - val_accuracy: 0.0000e+00 - val_loss: 7.2554
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.0500 - loss: 10.3445 - val_accuracy: 0.0000e+00 - val_loss: 4.6527
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1250 - loss: 7.5121 - val_accuracy: 0.0000e+00 - val_loss: 4.8845
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1750 - loss: 7.1705 - val_accuracy: 0.0000e+00 - val_loss: 4.0086
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1000 - loss: 6.1509 - val_accuracy: 0.0000e+00 - val_loss: 4.2521
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0750 - loss: 7.3977 - val_accuracy: 0.0000e+00 - val_loss: 3.1253
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.1750 - loss: 7.4897 - val_accuracy: 0.0000e+00 - val_loss: 4.6777
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.0750 - loss: 7.7342 - val_accuracy: 0.0000e+00 - val_loss: 5.2145
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.1500 - loss: 5.7230 - val_accuracy: 0.0000e+00 - val_loss: 4.1793
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1500 - loss: 6.6299 - val_accuracy: 0.0000e+00 - val_loss: 4.1550
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1500 - loss: 6.7919 - val_accuracy: 0.0500 - val_loss: 3.3090
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1000 - loss: 6.9138 - val_accuracy: 0.0000e+00 - val_loss: 3.4788
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1250 - loss: 6.5470 - val_accuracy: 0.0500 - val_loss: 3.1213
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1500 - loss: 6.5568 - val_accuracy: 0.0000e+00 - val_loss: 4.3969
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2250 - loss: 6.8765 - val_accuracy: 0.0500 - val_loss: 3.4118
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2000 - loss: 6.8735 - val_accuracy: 0.1500 - val_loss: 2.7455
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1750 - loss: 7.0304 - val_accuracy: 0.0500 - val_loss: 3.2823
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1250 - loss: 7.1085 - val_accuracy: 0.1000 - val_loss: 3.1339
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1000 - loss: 6.6374 - val_accuracy: 0.1000 - val_loss: 2.7907
# Epoch 22/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1250 - loss: 6.7681 - val_accuracy: 0.2500 - val_loss: 2.3793
# Epoch 23/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1500 - loss: 6.7366 - val_accuracy: 0.1000 - val_loss: 3.1308
# Epoch 24/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1250 - loss: 6.9016 - val_accuracy: 0.1500 - val_loss: 2.9318
# Epoch 25/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1000 - loss: 5.7183 - val_accuracy: 0.0500 - val_loss: 3.7007
# Epoch 26/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0750 - loss: 6.5843 - val_accuracy: 0.0500 - val_loss: 2.9227
# Epoch 27/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1000 - loss: 6.6664 - val_accuracy: 0.0500 - val_loss: 3.5728
# Epoch 28/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1000 - loss: 8.1400 - val_accuracy: 0.0500 - val_loss: 3.6216
# Epoch 29/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1250 - loss: 5.0093 - val_accuracy: 0.0500 - val_loss: 4.7841
# Epoch 30/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1750 - loss: 6.3823 - val_accuracy: 0.0500 - val_loss: 3.7710
# Epoch 31/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1500 - loss: 6.4639 - val_accuracy: 0.0500 - val_loss: 3.1225
# Epoch 32/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2000 - loss: 6.1774 - val_accuracy: 0.1500 - val_loss: 4.3296
# Epoch 33/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1750 - loss: 6.5796 - val_accuracy: 0.0500 - val_loss: 3.6280
# Epoch 34/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1500 - loss: 6.7815 - val_accuracy: 0.0000e+00 - val_loss: 4.9750
# Epoch 35/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2250 - loss: 5.1137 - val_accuracy: 0.0500 - val_loss: 3.8868
# Epoch 36/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1750 - loss: 6.3635 - val_accuracy: 0.0500 - val_loss: 4.4826
# Epoch 37/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1250 - loss: 6.4750 - val_accuracy: 0.0500 - val_loss: 3.3627
# Epoch 38/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2750 - loss: 5.1859 - val_accuracy: 0.0500 - val_loss: 4.0306
# Epoch 39/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1500 - loss: 6.4104 - val_accuracy: 0.0500 - val_loss: 4.1660
# Epoch 40/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1250 - loss: 7.0211 - val_accuracy: 0.0500 - val_loss: 4.3587
# Epoch 41/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1250 - loss: 5.4272 - val_accuracy: 0.0500 - val_loss: 2.9620
# Epoch 42/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1750 - loss: 6.2969 - val_accuracy: 0.0500 - val_loss: 3.2469
# Epoch 43/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2250 - loss: 5.9416 - val_accuracy: 0.2500 - val_loss: 2.1998
# Epoch 44/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0750 - loss: 7.4693 - val_accuracy: 0.0500 - val_loss: 2.7507
# Epoch 45/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1250 - loss: 6.6576 - val_accuracy: 0.0500 - val_loss: 3.9145
# Epoch 46/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1750 - loss: 5.4548 - val_accuracy: 0.0500 - val_loss: 3.3917
# Epoch 47/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1000 - loss: 6.0777 - val_accuracy: 0.0500 - val_loss: 3.0075
# Epoch 48/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2250 - loss: 5.6504 - val_accuracy: 0.0500 - val_loss: 2.7105
# Epoch 49/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1500 - loss: 5.5627 - val_accuracy: 0.0500 - val_loss: 3.8759
# Epoch 50/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2000 - loss: 4.6004 - val_accuracy: 0.0500 - val_loss: 3.4504
# Epoch 51/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1750 - loss: 6.6947 - val_accuracy: 0.0500 - val_loss: 3.1652
# Epoch 52/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2000 - loss: 4.8277 - val_accuracy: 0.0500 - val_loss: 2.4893
# Epoch 53/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1750 - loss: 5.8710 - val_accuracy: 0.0500 - val_loss: 3.1561
# Epoch 54/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1750 - loss: 4.9836 - val_accuracy: 0.0500 - val_loss: 3.0242
# Epoch 55/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2000 - loss: 5.2019 - val_accuracy: 0.1000 - val_loss: 2.2797
# Epoch 56/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1250 - loss: 6.1196 - val_accuracy: 0.2500 - val_loss: 2.1243
# Epoch 57/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1250 - loss: 5.7874 - val_accuracy: 0.0500 - val_loss: 2.4323
# Epoch 58/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1750 - loss: 6.8818 - val_accuracy: 0.0500 - val_loss: 2.4976
# Epoch 59/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1500 - loss: 5.8610 - val_accuracy: 0.0500 - val_loss: 2.2747
# Epoch 60/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1000 - loss: 5.9046 - val_accuracy: 0.0500 - val_loss: 3.0953
# Epoch 61/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2500 - loss: 4.6996 - val_accuracy: 0.0500 - val_loss: 3.3018
# Epoch 62/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.1750 - loss: 5.3229 - val_accuracy: 0.0500 - val_loss: 2.8528
# Epoch 63/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1250 - loss: 6.3603 - val_accuracy: 0.0500 - val_loss: 2.6947
# Epoch 64/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1500 - loss: 4.9866 - val_accuracy: 0.0500 - val_loss: 2.7402
# Epoch 65/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1250 - loss: 6.2972 - val_accuracy: 0.0500 - val_loss: 3.0217
# Epoch 66/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1500 - loss: 5.6036 - val_accuracy: 0.0500 - val_loss: 3.5295
# Epoch 67/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1500 - loss: 6.3688 - val_accuracy: 0.0500 - val_loss: 2.8879
# Epoch 68/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2000 - loss: 5.2864 - val_accuracy: 0.1000 - val_loss: 2.4456
# Epoch 69/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2000 - loss: 4.4832 - val_accuracy: 0.0500 - val_loss: 2.7735
# Epoch 70/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1750 - loss: 5.7962 - val_accuracy: 0.0500 - val_loss: 2.6675
# Epoch 71/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1750 - loss: 5.0132 - val_accuracy: 0.0500 - val_loss: 2.6041
# Epoch 72/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1000 - loss: 5.1846 - val_accuracy: 0.0500 - val_loss: 3.0210
# Epoch 73/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.1750 - loss: 5.9079 - val_accuracy: 0.0500 - val_loss: 3.3468
# Epoch 74/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.1500 - loss: 5.5477 - val_accuracy: 0.0500 - val_loss: 3.9710
# Epoch 75/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3000 - loss: 5.1268 - val_accuracy: 0.0500 - val_loss: 2.4552
# Epoch 76/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1500 - loss: 5.2487 - val_accuracy: 0.1500 - val_loss: 2.9838
# Epoch 77/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1000 - loss: 6.0509 - val_accuracy: 0.2500 - val_loss: 2.9780
# Epoch 78/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0250 - loss: 6.1228 - val_accuracy: 0.0500 - val_loss: 2.7810
# Epoch 79/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2500 - loss: 4.7054 - val_accuracy: 0.0500 - val_loss: 2.6565
# Epoch 80/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2000 - loss: 3.9097 - val_accuracy: 0.0500 - val_loss: 2.9091
# Epoch 81/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2250 - loss: 5.3232 - val_accuracy: 0.0500 - val_loss: 3.4430
# Epoch 82/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2250 - loss: 4.8214 - val_accuracy: 0.0500 - val_loss: 3.3459
# Epoch 83/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1750 - loss: 5.8904 - val_accuracy: 0.0500 - val_loss: 2.7022
# Epoch 84/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1750 - loss: 4.2684 - val_accuracy: 0.0500 - val_loss: 3.2020
# Epoch 85/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1750 - loss: 4.6482 - val_accuracy: 0.0500 - val_loss: 3.0143
# Epoch 86/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2000 - loss: 4.8566 - val_accuracy: 0.1000 - val_loss: 2.3559
# Epoch 87/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1750 - loss: 4.8649 - val_accuracy: 0.0500 - val_loss: 3.0121
# Epoch 88/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3250 - loss: 4.1119 - val_accuracy: 0.0500 - val_loss: 2.7644
# Epoch 89/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2000 - loss: 4.8526 - val_accuracy: 0.0500 - val_loss: 2.8239
# Epoch 90/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1250 - loss: 4.0283 - val_accuracy: 0.0500 - val_loss: 2.7438
# Epoch 91/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2000 - loss: 4.6167 - val_accuracy: 0.0500 - val_loss: 2.1680
# Epoch 92/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.1750 - loss: 4.9923 - val_accuracy: 0.0500 - val_loss: 2.4857
# Epoch 93/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1250 - loss: 4.7144 - val_accuracy: 0.0500 - val_loss: 3.0444
# Epoch 94/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2250 - loss: 4.5438 - val_accuracy: 0.0500 - val_loss: 2.0234
# Epoch 95/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1750 - loss: 4.8985 - val_accuracy: 0.0500 - val_loss: 2.5372
# Epoch 96/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1750 - loss: 5.2383 - val_accuracy: 0.1000 - val_loss: 2.6186
# Epoch 97/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2250 - loss: 4.2623 - val_accuracy: 0.1000 - val_loss: 2.1510
# Epoch 98/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1500 - loss: 4.5480 - val_accuracy: 0.0500 - val_loss: 3.0063
# Epoch 99/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1750 - loss: 4.5583 - val_accuracy: 0.1000 - val_loss: 2.1931
# Epoch 100/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1750 - loss: 5.1215 - val_accuracy: 0.1000 - val_loss: 2.5428
# Epoch 101/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1750 - loss: 4.5930 - val_accuracy: 0.0500 - val_loss: 2.4003
# Epoch 102/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2000 - loss: 5.4402 - val_accuracy: 0.0500 - val_loss: 2.3573
# Epoch 103/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1250 - loss: 4.0070 - val_accuracy: 0.0500 - val_loss: 2.8240
# Epoch 104/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2500 - loss: 4.4662 - val_accuracy: 0.1000 - val_loss: 2.5752
# Epoch 105/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.1750 - loss: 4.2687 - val_accuracy: 0.0500 - val_loss: 2.6701
# Epoch 106/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.3000 - loss: 4.3356 - val_accuracy: 0.1000 - val_loss: 2.9812
# Epoch 107/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.2750 - loss: 4.8737 - val_accuracy: 0.3500 - val_loss: 1.8435
# Epoch 108/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.1250 - loss: 4.6263 - val_accuracy: 0.0500 - val_loss: 2.1565
# Epoch 109/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.1750 - loss: 5.1785 - val_accuracy: 0.2500 - val_loss: 2.2874
# Epoch 110/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.1750 - loss: 4.7433 - val_accuracy: 0.2500 - val_loss: 1.9214
# Epoch 111/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2000 - loss: 5.0284 - val_accuracy: 0.0500 - val_loss: 2.4510
# Epoch 112/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.1500 - loss: 5.6748 - val_accuracy: 0.2500 - val_loss: 2.2251
# Epoch 113/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.2500 - loss: 4.4149 - val_accuracy: 0.0500 - val_loss: 2.3593
# Epoch 114/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.1750 - loss: 4.9305 - val_accuracy: 0.0500 - val_loss: 2.9146
# Epoch 115/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1750 - loss: 4.2251 - val_accuracy: 0.0500 - val_loss: 2.7341
# Epoch 116/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1250 - loss: 5.2650 - val_accuracy: 0.0500 - val_loss: 2.6767
# Epoch 117/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3000 - loss: 3.9063 - val_accuracy: 0.0500 - val_loss: 2.1996
# Epoch 118/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.1500 - loss: 4.0103 - val_accuracy: 0.1000 - val_loss: 2.3857
# Epoch 119/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2250 - loss: 3.7813 - val_accuracy: 0.0500 - val_loss: 2.2842
# Epoch 120/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.2000 - loss: 3.8880 - val_accuracy: 0.1500 - val_loss: 2.6330
# Epoch 121/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2750 - loss: 4.1140 - val_accuracy: 0.2000 - val_loss: 2.3816
# Epoch 122/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2250 - loss: 4.5284 - val_accuracy: 0.2500 - val_loss: 2.3346
# Epoch 123/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.2250 - loss: 4.2728 - val_accuracy: 0.1000 - val_loss: 2.3562
# Epoch 124/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3000 - loss: 2.8797 - val_accuracy: 0.1000 - val_loss: 2.3189
# Epoch 125/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1750 - loss: 4.5026 - val_accuracy: 0.4000 - val_loss: 1.9002
# Epoch 126/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2000 - loss: 3.8324 - val_accuracy: 0.0500 - val_loss: 2.7833
# Epoch 127/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.2250 - loss: 4.0348 - val_accuracy: 0.1000 - val_loss: 2.7942
# Epoch 128/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2250 - loss: 4.2599 - val_accuracy: 0.0500 - val_loss: 3.1220
# Epoch 129/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.1500 - loss: 4.3756 - val_accuracy: 0.1000 - val_loss: 2.5087
# Epoch 130/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1750 - loss: 4.5153 - val_accuracy: 0.1000 - val_loss: 2.3307
# Epoch 131/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.1250 - loss: 4.6975 - val_accuracy: 0.0500 - val_loss: 2.0598
# Epoch 132/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.2000 - loss: 4.2971 - val_accuracy: 0.1000 - val_loss: 2.3017
# Epoch 133/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3250 - loss: 3.5974 - val_accuracy: 0.0500 - val_loss: 2.5053
# Epoch 134/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2250 - loss: 4.2202 - val_accuracy: 0.1500 - val_loss: 2.4497
# Epoch 135/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3250 - loss: 3.4729 - val_accuracy: 0.1000 - val_loss: 2.3073
# Epoch 136/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2000 - loss: 4.0385 - val_accuracy: 0.1000 - val_loss: 2.2915
# Epoch 137/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.2500 - loss: 2.6870 - val_accuracy: 0.1000 - val_loss: 2.4807
# Epoch 138/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2250 - loss: 4.6959 - val_accuracy: 0.1500 - val_loss: 2.4555
# Epoch 139/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.1750 - loss: 4.0846 - val_accuracy: 0.2500 - val_loss: 1.8638
# Epoch 140/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2250 - loss: 4.2906 - val_accuracy: 0.3000 - val_loss: 1.7645
# Epoch 141/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3000 - loss: 2.9295 - val_accuracy: 0.1500 - val_loss: 1.9879
# Epoch 142/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2750 - loss: 3.7420 - val_accuracy: 0.0500 - val_loss: 2.3755
# Epoch 143/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3000 - loss: 4.2046 - val_accuracy: 0.3500 - val_loss: 1.9294
# Epoch 144/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3500 - loss: 4.3649 - val_accuracy: 0.1000 - val_loss: 2.4599
# Epoch 145/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.1750 - loss: 4.4952 - val_accuracy: 0.1500 - val_loss: 2.0679
# Epoch 146/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2250 - loss: 3.2693 - val_accuracy: 0.2500 - val_loss: 1.7869
# Epoch 147/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.2500 - loss: 3.9429 - val_accuracy: 0.0500 - val_loss: 2.5065
# Epoch 148/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2500 - loss: 4.0069 - val_accuracy: 0.0500 - val_loss: 2.2282
# Epoch 149/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.1750 - loss: 4.2253 - val_accuracy: 0.2500 - val_loss: 2.4089
# Epoch 150/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2750 - loss: 4.0639 - val_accuracy: 0.2000 - val_loss: 2.1331
# Epoch 151/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.2250 - loss: 3.7096 - val_accuracy: 0.0500 - val_loss: 2.3379
# Epoch 152/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2250 - loss: 4.0821 - val_accuracy: 0.0500 - val_loss: 2.6325
# Epoch 153/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2750 - loss: 3.2422 - val_accuracy: 0.0500 - val_loss: 2.5809
# Epoch 154/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3000 - loss: 3.1893 - val_accuracy: 0.1500 - val_loss: 1.7797
# Epoch 155/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2000 - loss: 3.6551 - val_accuracy: 0.2000 - val_loss: 2.1991
# Epoch 156/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3000 - loss: 3.2506 - val_accuracy: 0.2500 - val_loss: 1.9215
# Epoch 157/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2000 - loss: 3.6125 - val_accuracy: 0.2500 - val_loss: 2.0072
# Epoch 158/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.2250 - loss: 4.6557 - val_accuracy: 0.0500 - val_loss: 2.2698
# Epoch 159/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3500 - loss: 3.2643 - val_accuracy: 0.1000 - val_loss: 2.0487
# Epoch 160/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2000 - loss: 4.2122 - val_accuracy: 0.0500 - val_loss: 2.1894
# Epoch 161/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3500 - loss: 3.2611 - val_accuracy: 0.0500 - val_loss: 3.0896
# Epoch 162/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.2250 - loss: 3.3586 - val_accuracy: 0.2500 - val_loss: 1.9907
# Epoch 163/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3250 - loss: 3.4255 - val_accuracy: 0.3000 - val_loss: 1.9604
# Epoch 164/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.1750 - loss: 3.4352 - val_accuracy: 0.2000 - val_loss: 1.8420
# Epoch 165/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3250 - loss: 3.5844 - val_accuracy: 0.1000 - val_loss: 2.2602
# Epoch 166/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2500 - loss: 3.4163 - val_accuracy: 0.1000 - val_loss: 1.9287
# Epoch 167/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3250 - loss: 2.7377 - val_accuracy: 0.0500 - val_loss: 2.2964
# Epoch 168/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3250 - loss: 3.7844 - val_accuracy: 0.1000 - val_loss: 1.8527
# Epoch 169/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.3000 - loss: 3.4422 - val_accuracy: 0.2500 - val_loss: 2.0924
# Epoch 170/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2000 - loss: 3.5972 - val_accuracy: 0.1500 - val_loss: 2.1355
# Epoch 171/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2250 - loss: 3.7812 - val_accuracy: 0.2500 - val_loss: 2.0807
# Epoch 172/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.1500 - loss: 3.7003 - val_accuracy: 0.3000 - val_loss: 1.7948
# Epoch 173/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3250 - loss: 3.1863 - val_accuracy: 0.2000 - val_loss: 1.8604
# Epoch 174/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3000 - loss: 3.2461 - val_accuracy: 0.2500 - val_loss: 2.0622
# Epoch 175/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3500 - loss: 3.2716 - val_accuracy: 0.2000 - val_loss: 1.9368
# Epoch 176/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.2000 - loss: 3.1252 - val_accuracy: 0.1500 - val_loss: 2.0116
# Epoch 177/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2000 - loss: 3.4998 - val_accuracy: 0.0500 - val_loss: 2.0819
# Epoch 178/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2500 - loss: 3.0313 - val_accuracy: 0.1000 - val_loss: 1.9767
# Epoch 179/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.1250 - loss: 3.4073 - val_accuracy: 0.1500 - val_loss: 2.0789
# Epoch 180/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2250 - loss: 3.4575 - val_accuracy: 0.2000 - val_loss: 1.9416
# Epoch 181/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2000 - loss: 3.7351 - val_accuracy: 0.2000 - val_loss: 1.8174
# Epoch 182/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2500 - loss: 3.1662 - val_accuracy: 0.2500 - val_loss: 1.7878
# Epoch 183/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2500 - loss: 3.0291 - val_accuracy: 0.2500 - val_loss: 2.0658
# Epoch 184/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.2000 - loss: 3.5231 - val_accuracy: 0.2500 - val_loss: 1.7893
# Epoch 185/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.2750 - loss: 3.4583 - val_accuracy: 0.2500 - val_loss: 2.0149
# Epoch 186/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.2250 - loss: 3.6265 - val_accuracy: 0.1500 - val_loss: 2.0759
# Epoch 187/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.2250 - loss: 3.8114 - val_accuracy: 0.2000 - val_loss: 2.2279
# Epoch 188/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3500 - loss: 3.4834 - val_accuracy: 0.2500 - val_loss: 2.0886
# Epoch 189/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3000 - loss: 2.4058 - val_accuracy: 0.2500 - val_loss: 2.0724
# Epoch 190/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.2250 - loss: 3.6552 - val_accuracy: 0.1000 - val_loss: 1.9926
# Epoch 191/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2500 - loss: 3.4585 - val_accuracy: 0.3500 - val_loss: 1.7850
# Epoch 192/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2750 - loss: 3.5506 - val_accuracy: 0.5000 - val_loss: 1.6182
# Epoch 193/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2500 - loss: 3.3395 - val_accuracy: 0.1000 - val_loss: 1.8377
# Epoch 194/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.2500 - loss: 2.9816 - val_accuracy: 0.1000 - val_loss: 1.9722
# Epoch 195/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2500 - loss: 3.2089 - val_accuracy: 0.3000 - val_loss: 1.8926
# Epoch 196/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3000 - loss: 2.6620 - val_accuracy: 0.1500 - val_loss: 1.9200
# Epoch 197/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2000 - loss: 3.0826 - val_accuracy: 0.2500 - val_loss: 1.8851
# Epoch 198/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3000 - loss: 2.6282 - val_accuracy: 0.1000 - val_loss: 1.9794
# Epoch 199/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2500 - loss: 3.2494 - val_accuracy: 0.3000 - val_loss: 1.8408
# Epoch 200/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3500 - loss: 2.0261 - val_accuracy: 0.0500 - val_loss: 2.2075
# Epoch 201/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3000 - loss: 3.0894 - val_accuracy: 0.1000 - val_loss: 2.0914
# Epoch 202/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5250 - loss: 2.5245 - val_accuracy: 0.2000 - val_loss: 1.7823
# Epoch 203/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3000 - loss: 3.4588 - val_accuracy: 0.1000 - val_loss: 2.1239
# Epoch 204/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.2000 - loss: 3.1886 - val_accuracy: 0.0500 - val_loss: 2.6439
# Epoch 205/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2250 - loss: 3.3979 - val_accuracy: 0.2000 - val_loss: 1.7545
# Epoch 206/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.2750 - loss: 2.9958 - val_accuracy: 0.3500 - val_loss: 1.6594
# Epoch 207/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2000 - loss: 3.3856 - val_accuracy: 0.1500 - val_loss: 1.9255
# Epoch 208/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2750 - loss: 3.1472 - val_accuracy: 0.1500 - val_loss: 1.9402
# Epoch 209/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2500 - loss: 2.9740 - val_accuracy: 0.2500 - val_loss: 2.0092
# Epoch 210/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3750 - loss: 2.9314 - val_accuracy: 0.1500 - val_loss: 1.9829
# Epoch 211/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3500 - loss: 2.9789 - val_accuracy: 0.1000 - val_loss: 2.2573
# Epoch 212/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2250 - loss: 2.9291 - val_accuracy: 0.1000 - val_loss: 2.1197
# Epoch 213/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3000 - loss: 2.5792 - val_accuracy: 0.1500 - val_loss: 2.1219
# Epoch 214/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3000 - loss: 3.2504 - val_accuracy: 0.1000 - val_loss: 2.3764
# Epoch 215/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2750 - loss: 2.7597 - val_accuracy: 0.1000 - val_loss: 2.3145
# Epoch 216/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3000 - loss: 2.8816 - val_accuracy: 0.2000 - val_loss: 1.9903
# Epoch 217/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3750 - loss: 2.3211 - val_accuracy: 0.1000 - val_loss: 2.1349
# Epoch 218/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3250 - loss: 2.8940 - val_accuracy: 0.3000 - val_loss: 1.8213
# Epoch 219/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2750 - loss: 2.9738 - val_accuracy: 0.4000 - val_loss: 1.8218
# Epoch 220/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2250 - loss: 3.2265 - val_accuracy: 0.2500 - val_loss: 1.6934
# Epoch 221/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2500 - loss: 2.9709 - val_accuracy: 0.4000 - val_loss: 1.6926
# Epoch 222/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3500 - loss: 2.2429 - val_accuracy: 0.3500 - val_loss: 1.7107
# Epoch 223/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3250 - loss: 2.6568 - val_accuracy: 0.4000 - val_loss: 1.6423
# Epoch 224/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3750 - loss: 2.5402 - val_accuracy: 0.3500 - val_loss: 1.7355
# Epoch 225/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.2250 - loss: 3.3303 - val_accuracy: 0.3500 - val_loss: 1.6330
# Epoch 226/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.4000 - loss: 2.6554 - val_accuracy: 0.3000 - val_loss: 1.8132
# Epoch 227/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2500 - loss: 2.7700 - val_accuracy: 0.2500 - val_loss: 1.6588
# Epoch 228/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3750 - loss: 3.0422 - val_accuracy: 0.2500 - val_loss: 2.0028
# Epoch 229/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3000 - loss: 2.3985 - val_accuracy: 0.0500 - val_loss: 2.6116
# Epoch 230/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2500 - loss: 2.8165 - val_accuracy: 0.3500 - val_loss: 1.6763
# Epoch 231/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4000 - loss: 2.3194 - val_accuracy: 0.2500 - val_loss: 2.0082
# Epoch 232/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3500 - loss: 2.6934 - val_accuracy: 0.1500 - val_loss: 2.1020
# Epoch 233/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3000 - loss: 2.1754 - val_accuracy: 0.3500 - val_loss: 1.7796
# Epoch 234/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3000 - loss: 2.5543 - val_accuracy: 0.1500 - val_loss: 1.8698
# Epoch 235/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3000 - loss: 3.0911 - val_accuracy: 0.2000 - val_loss: 1.9986
# Epoch 236/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3000 - loss: 2.8554 - val_accuracy: 0.3500 - val_loss: 1.5414
# Epoch 237/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.2500 - loss: 2.6967 - val_accuracy: 0.2500 - val_loss: 1.5657
# Epoch 238/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.2750 - loss: 2.7540 - val_accuracy: 0.4500 - val_loss: 1.3769
# Epoch 239/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3500 - loss: 2.4990 - val_accuracy: 0.5500 - val_loss: 1.5255
# Epoch 240/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.1500 - loss: 3.1360 - val_accuracy: 0.3000 - val_loss: 1.6283
# Epoch 241/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3500 - loss: 2.4070 - val_accuracy: 0.2500 - val_loss: 1.6137
# Epoch 242/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3000 - loss: 2.7335 - val_accuracy: 0.4500 - val_loss: 1.4782
# Epoch 243/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4250 - loss: 1.8755 - val_accuracy: 0.4000 - val_loss: 1.5709
# Epoch 244/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2000 - loss: 2.2287 - val_accuracy: 0.2500 - val_loss: 1.6005
# Epoch 245/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3000 - loss: 2.5646 - val_accuracy: 0.2000 - val_loss: 1.6952
# Epoch 246/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3000 - loss: 2.6386 - val_accuracy: 0.3000 - val_loss: 1.8875
# Epoch 247/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.3500 - loss: 2.5002 - val_accuracy: 0.1500 - val_loss: 1.8933
# Epoch 248/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2250 - loss: 2.9524 - val_accuracy: 0.3000 - val_loss: 1.5698
# Epoch 249/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2250 - loss: 2.2408 - val_accuracy: 0.4500 - val_loss: 1.5009
# Epoch 250/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2500 - loss: 2.5171 - val_accuracy: 0.3500 - val_loss: 1.4843
# Epoch 251/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3000 - loss: 2.2248 - val_accuracy: 0.4500 - val_loss: 1.5700
# Epoch 252/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2500 - loss: 2.7966 - val_accuracy: 0.3000 - val_loss: 1.6869
# Epoch 253/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4500 - loss: 2.4359 - val_accuracy: 0.3000 - val_loss: 1.7565
# Epoch 254/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3750 - loss: 2.1976 - val_accuracy: 0.5000 - val_loss: 1.4645
# Epoch 255/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3500 - loss: 2.6950 - val_accuracy: 0.3000 - val_loss: 1.6986
# Epoch 256/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3500 - loss: 2.5074 - val_accuracy: 0.3500 - val_loss: 1.5177
# Epoch 257/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3750 - loss: 1.9796 - val_accuracy: 0.4000 - val_loss: 1.4747
# Epoch 258/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3250 - loss: 2.1394 - val_accuracy: 0.2500 - val_loss: 1.5822
# Epoch 259/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3750 - loss: 2.5010 - val_accuracy: 0.4000 - val_loss: 1.5106
# Epoch 260/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3750 - loss: 2.3174 - val_accuracy: 0.4000 - val_loss: 1.4730
# Epoch 261/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3500 - loss: 2.4651 - val_accuracy: 0.2500 - val_loss: 1.6600
# Epoch 262/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3250 - loss: 2.0889 - val_accuracy: 0.2000 - val_loss: 2.1235
# Epoch 263/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2750 - loss: 2.2829 - val_accuracy: 0.2500 - val_loss: 1.8283
# Epoch 264/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3500 - loss: 2.2314 - val_accuracy: 0.2500 - val_loss: 1.8045
# Epoch 265/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4250 - loss: 1.8891 - val_accuracy: 0.3000 - val_loss: 1.7040
# Epoch 266/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2750 - loss: 2.8898 - val_accuracy: 0.3000 - val_loss: 1.7832
# Epoch 267/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3250 - loss: 2.4936 - val_accuracy: 0.3000 - val_loss: 1.5576
# Epoch 268/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3750 - loss: 1.9908 - val_accuracy: 0.2500 - val_loss: 1.9186
# Epoch 269/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4000 - loss: 2.2825 - val_accuracy: 0.4500 - val_loss: 1.5380
# Epoch 270/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3750 - loss: 2.4262 - val_accuracy: 0.4000 - val_loss: 1.6132
# Epoch 271/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3250 - loss: 2.2451 - val_accuracy: 0.4500 - val_loss: 1.6489
# Epoch 272/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4250 - loss: 2.2662 - val_accuracy: 0.3000 - val_loss: 1.5864
# Epoch 273/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4000 - loss: 2.6527 - val_accuracy: 0.4500 - val_loss: 1.4217
# Epoch 274/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3500 - loss: 2.4523 - val_accuracy: 0.2500 - val_loss: 1.8134
# Epoch 275/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.4000 - loss: 2.2897 - val_accuracy: 0.4500 - val_loss: 1.5499
# Epoch 276/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3500 - loss: 2.2755 - val_accuracy: 0.5500 - val_loss: 1.4073
# Epoch 277/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3500 - loss: 2.2358 - val_accuracy: 0.4000 - val_loss: 1.4962
# Epoch 278/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3250 - loss: 2.1596 - val_accuracy: 0.5000 - val_loss: 1.4622
# Epoch 279/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3500 - loss: 2.0422 - val_accuracy: 0.4000 - val_loss: 1.6370
# Epoch 280/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3250 - loss: 2.5352 - val_accuracy: 0.2500 - val_loss: 1.8186
# Epoch 281/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3000 - loss: 2.5519 - val_accuracy: 0.2000 - val_loss: 1.8431
# Epoch 282/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3500 - loss: 2.5706 - val_accuracy: 0.4500 - val_loss: 1.5015
# Epoch 283/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.3250 - loss: 1.9671 - val_accuracy: 0.3000 - val_loss: 1.7465
# Epoch 284/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4250 - loss: 1.8389 - val_accuracy: 0.3500 - val_loss: 1.5773
# Epoch 285/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3750 - loss: 2.3857 - val_accuracy: 0.4000 - val_loss: 1.5557
# Epoch 286/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3500 - loss: 2.2374 - val_accuracy: 0.2500 - val_loss: 1.7664
# Epoch 287/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2750 - loss: 2.4508 - val_accuracy: 0.2000 - val_loss: 1.8824
# Epoch 288/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4250 - loss: 2.1122 - val_accuracy: 0.2500 - val_loss: 1.6779
# Epoch 289/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3000 - loss: 1.9323 - val_accuracy: 0.3500 - val_loss: 1.4409
# Epoch 290/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.1750 - loss: 2.7483 - val_accuracy: 0.3500 - val_loss: 1.6028
# Epoch 291/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3500 - loss: 2.3758 - val_accuracy: 0.4500 - val_loss: 1.4475
# Epoch 292/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4250 - loss: 2.0332 - val_accuracy: 0.3500 - val_loss: 1.6038
# Epoch 293/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3500 - loss: 2.3240 - val_accuracy: 0.5500 - val_loss: 1.4408
# Epoch 294/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3250 - loss: 2.1178 - val_accuracy: 0.5000 - val_loss: 1.4284
# Epoch 295/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3250 - loss: 2.0756 - val_accuracy: 0.4500 - val_loss: 1.4628
# Epoch 296/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3000 - loss: 2.1988 - val_accuracy: 0.5000 - val_loss: 1.3020
# Epoch 297/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3500 - loss: 2.4673 - val_accuracy: 0.3500 - val_loss: 1.5560
# Epoch 298/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3000 - loss: 2.4162 - val_accuracy: 0.3000 - val_loss: 1.6623
# Epoch 299/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3250 - loss: 2.1527 - val_accuracy: 0.4000 - val_loss: 1.5566
# Epoch 300/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3500 - loss: 2.1049 - val_accuracy: 0.3500 - val_loss: 1.7484
# Epoch 301/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3750 - loss: 2.2022 - val_accuracy: 0.3000 - val_loss: 1.6953
# Epoch 302/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3750 - loss: 2.2476 - val_accuracy: 0.3500 - val_loss: 1.6056
# Epoch 303/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3250 - loss: 1.7789 - val_accuracy: 0.3000 - val_loss: 1.5837
# Epoch 304/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3750 - loss: 2.1397 - val_accuracy: 0.5500 - val_loss: 1.3494
# Epoch 305/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.2250 - loss: 2.5672 - val_accuracy: 0.5000 - val_loss: 1.4724
# Epoch 306/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4250 - loss: 1.8301 - val_accuracy: 0.3500 - val_loss: 1.6345
# Epoch 307/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4250 - loss: 1.9878 - val_accuracy: 0.2500 - val_loss: 1.5633
# Epoch 308/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2500 - loss: 2.3335 - val_accuracy: 0.3000 - val_loss: 1.6803
# Epoch 309/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4500 - loss: 1.9523 - val_accuracy: 0.3000 - val_loss: 1.6275
# Epoch 310/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3250 - loss: 2.1898 - val_accuracy: 0.2500 - val_loss: 1.8621
# Epoch 311/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3500 - loss: 2.3562 - val_accuracy: 0.4000 - val_loss: 1.5640
# Epoch 312/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.3500 - loss: 2.1584 - val_accuracy: 0.3500 - val_loss: 1.5920
# Epoch 313/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4000 - loss: 1.9900 - val_accuracy: 0.4000 - val_loss: 1.5084
# Epoch 314/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3250 - loss: 1.9164 - val_accuracy: 0.2000 - val_loss: 1.7931
# Epoch 315/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4000 - loss: 1.7876 - val_accuracy: 0.4500 - val_loss: 1.4978
# Epoch 316/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3500 - loss: 1.8629 - val_accuracy: 0.3500 - val_loss: 1.5918
# Epoch 317/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3500 - loss: 2.0491 - val_accuracy: 0.5000 - val_loss: 1.3922
# Epoch 318/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.3500 - loss: 2.1192 - val_accuracy: 0.5500 - val_loss: 1.3756
# Epoch 319/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3250 - loss: 2.0717 - val_accuracy: 0.3000 - val_loss: 1.5986
# Epoch 320/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5000 - loss: 1.9359 - val_accuracy: 0.4000 - val_loss: 1.5053
# Epoch 321/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3500 - loss: 2.2747 - val_accuracy: 0.4500 - val_loss: 1.4993
# Epoch 322/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3500 - loss: 2.0336 - val_accuracy: 0.3500 - val_loss: 1.6031
# Epoch 323/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3750 - loss: 1.6346 - val_accuracy: 0.3500 - val_loss: 1.5609
# Epoch 324/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4500 - loss: 1.9026 - val_accuracy: 0.3500 - val_loss: 1.5695
# Epoch 325/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3750 - loss: 1.8828 - val_accuracy: 0.3500 - val_loss: 1.6843
# Epoch 326/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5250 - loss: 1.5045 - val_accuracy: 0.5500 - val_loss: 1.3295
# Epoch 327/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4750 - loss: 1.4737 - val_accuracy: 0.3000 - val_loss: 1.5563
# Epoch 328/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2750 - loss: 2.1575 - val_accuracy: 0.4000 - val_loss: 1.4927
# Epoch 329/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3750 - loss: 1.8207 - val_accuracy: 0.4000 - val_loss: 1.3305
# Epoch 330/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4250 - loss: 1.8515 - val_accuracy: 0.3000 - val_loss: 1.6188
# Epoch 331/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4500 - loss: 1.9345 - val_accuracy: 0.2000 - val_loss: 1.8092
# Epoch 332/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4000 - loss: 2.1522 - val_accuracy: 0.2500 - val_loss: 1.6681
# Epoch 333/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4000 - loss: 1.7967 - val_accuracy: 0.5000 - val_loss: 1.4553
# Epoch 334/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3250 - loss: 2.3366 - val_accuracy: 0.3500 - val_loss: 1.5696
# Epoch 335/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4000 - loss: 2.0962 - val_accuracy: 0.4000 - val_loss: 1.3861
# Epoch 336/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3250 - loss: 1.9008 - val_accuracy: 0.3500 - val_loss: 1.4438
# Epoch 337/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5750 - loss: 1.4802 - val_accuracy: 0.4500 - val_loss: 1.4057
# Epoch 338/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4250 - loss: 2.0082 - val_accuracy: 0.4500 - val_loss: 1.2896
# Epoch 339/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.4000 - loss: 1.8191 - val_accuracy: 0.4000 - val_loss: 1.4713
# Epoch 340/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3500 - loss: 2.0027 - val_accuracy: 0.3500 - val_loss: 1.5358
# Epoch 341/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4000 - loss: 1.9716 - val_accuracy: 0.3000 - val_loss: 1.5353
# Epoch 342/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4000 - loss: 1.7047 - val_accuracy: 0.6000 - val_loss: 1.2479
# Epoch 343/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4000 - loss: 1.7715 - val_accuracy: 0.6000 - val_loss: 1.3403
# Epoch 344/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3000 - loss: 2.0331 - val_accuracy: 0.4000 - val_loss: 1.4895
# Epoch 345/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4250 - loss: 1.6981 - val_accuracy: 0.4500 - val_loss: 1.4672
# Epoch 346/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5000 - loss: 1.6842 - val_accuracy: 0.4500 - val_loss: 1.3821
# Epoch 347/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5250 - loss: 1.6279 - val_accuracy: 0.6500 - val_loss: 1.2378
# Epoch 348/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5000 - loss: 1.5653 - val_accuracy: 0.7000 - val_loss: 1.2868
# Epoch 349/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.4750 - loss: 1.7328 - val_accuracy: 0.3000 - val_loss: 1.5766
# Epoch 350/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4000 - loss: 2.0924 - val_accuracy: 0.2500 - val_loss: 1.5642
# Epoch 351/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4000 - loss: 1.7415 - val_accuracy: 0.3500 - val_loss: 1.5575
# Epoch 352/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4500 - loss: 1.8208 - val_accuracy: 0.5500 - val_loss: 1.4010
# Epoch 353/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.4500 - loss: 1.7435 - val_accuracy: 0.6000 - val_loss: 1.2941
# Epoch 354/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5000 - loss: 1.6640 - val_accuracy: 0.5000 - val_loss: 1.3293
# Epoch 355/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3750 - loss: 1.7719 - val_accuracy: 0.6500 - val_loss: 1.2597
# Epoch 356/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4250 - loss: 2.0870 - val_accuracy: 0.5500 - val_loss: 1.3113
# Epoch 357/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5000 - loss: 1.7122 - val_accuracy: 0.3000 - val_loss: 1.5255
# Epoch 358/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.4000 - loss: 1.9141 - val_accuracy: 0.3500 - val_loss: 1.5417
# Epoch 359/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4250 - loss: 1.8227 - val_accuracy: 0.1500 - val_loss: 1.6957
# Epoch 360/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4500 - loss: 1.5871 - val_accuracy: 0.4000 - val_loss: 1.4271
# Epoch 361/1000
# ...
# Epoch 878/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8000 - loss: 0.5890 - val_accuracy: 0.7500 - val_loss: 0.8069
# Epoch 879/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6750 - loss: 0.7860 - val_accuracy: 0.7000 - val_loss: 0.7740
# Epoch 880/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6750 - loss: 0.7846 - val_accuracy: 0.6500 - val_loss: 0.7818
# Epoch 881/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6500 - loss: 0.8903 - val_accuracy: 0.6500 - val_loss: 0.9449
# Epoch 882/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8000 - loss: 0.6720 - val_accuracy: 0.5500 - val_loss: 0.9814
# Epoch 883/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7250 - loss: 0.6543 - val_accuracy: 0.7500 - val_loss: 0.9193
# Epoch 884/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7500 - loss: 0.7339 - val_accuracy: 0.7500 - val_loss: 0.8123
# Epoch 885/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8750 - loss: 0.5894 - val_accuracy: 0.6500 - val_loss: 0.8854
# Epoch 886/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7250 - loss: 0.7765 - val_accuracy: 0.6000 - val_loss: 0.9183
# Epoch 887/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7750 - loss: 0.7008 - val_accuracy: 0.7000 - val_loss: 0.8069
# Epoch 888/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7500 - loss: 0.7873 - val_accuracy: 0.7000 - val_loss: 0.8263
# Epoch 889/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7250 - loss: 0.6373 - val_accuracy: 0.7000 - val_loss: 0.8892
# Epoch 890/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7500 - loss: 0.6738 - val_accuracy: 0.7000 - val_loss: 0.7672
# Epoch 891/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8750 - loss: 0.5414 - val_accuracy: 0.6500 - val_loss: 0.8438
# Epoch 892/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7750 - loss: 0.6001 - val_accuracy: 0.6000 - val_loss: 0.8457
# Epoch 893/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6750 - loss: 0.8028 - val_accuracy: 0.7000 - val_loss: 0.8101
# Epoch 894/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7000 - loss: 0.8337 - val_accuracy: 0.6500 - val_loss: 0.9179
# Epoch 895/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7750 - loss: 0.6097 - val_accuracy: 0.7000 - val_loss: 0.8442
# Epoch 896/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8000 - loss: 0.6371 - val_accuracy: 0.7000 - val_loss: 0.8611
# Epoch 897/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8250 - loss: 0.6646 - val_accuracy: 0.6000 - val_loss: 1.0367
# Epoch 898/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7750 - loss: 0.7144 - val_accuracy: 0.6500 - val_loss: 0.9515
# Epoch 899/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7500 - loss: 0.7419 - val_accuracy: 0.7000 - val_loss: 0.8931
# Epoch 900/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8000 - loss: 0.6658 - val_accuracy: 0.7000 - val_loss: 0.8567
# Epoch 901/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7500 - loss: 0.6985 - val_accuracy: 0.6500 - val_loss: 0.8480
# Epoch 902/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8250 - loss: 0.5919 - val_accuracy: 0.6500 - val_loss: 0.8504
# Epoch 903/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7500 - loss: 0.8015 - val_accuracy: 0.7000 - val_loss: 0.8085
# Epoch 904/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7000 - loss: 0.9510 - val_accuracy: 0.6500 - val_loss: 0.8423
# Epoch 905/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8250 - loss: 0.5981 - val_accuracy: 0.7000 - val_loss: 0.7631
# Epoch 906/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7000 - loss: 0.7311 - val_accuracy: 0.7000 - val_loss: 0.7777
# Epoch 907/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7750 - loss: 0.6019 - val_accuracy: 0.7500 - val_loss: 0.8258
# Epoch 908/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7500 - loss: 0.6987 - val_accuracy: 0.7000 - val_loss: 0.7630
# Epoch 909/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.7500 - loss: 0.7051 - val_accuracy: 0.6500 - val_loss: 0.8234
# Epoch 910/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8250 - loss: 0.7645 - val_accuracy: 0.6500 - val_loss: 1.0143
# Epoch 911/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8250 - loss: 0.5886 - val_accuracy: 0.6000 - val_loss: 0.9092
# Epoch 912/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7750 - loss: 0.8531 - val_accuracy: 0.6000 - val_loss: 0.9366
# Epoch 913/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6250 - loss: 0.9365 - val_accuracy: 0.7000 - val_loss: 0.8761
# Epoch 914/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7750 - loss: 0.7307 - val_accuracy: 0.6500 - val_loss: 0.7957
# Epoch 915/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7000 - loss: 0.7308 - val_accuracy: 0.6500 - val_loss: 0.8006
# Epoch 916/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8500 - loss: 0.6290 - val_accuracy: 0.6500 - val_loss: 0.8780
# Epoch 917/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6500 - loss: 0.7866 - val_accuracy: 0.6500 - val_loss: 0.9064
# Epoch 918/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8500 - loss: 0.5628 - val_accuracy: 0.6000 - val_loss: 0.9956
# Epoch 919/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8000 - loss: 0.6282 - val_accuracy: 0.6500 - val_loss: 0.8950
# Epoch 920/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7250 - loss: 0.6084 - val_accuracy: 0.6500 - val_loss: 0.8384
# Epoch 921/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7750 - loss: 0.6948 - val_accuracy: 0.6500 - val_loss: 0.9215
# Epoch 922/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7750 - loss: 0.6115 - val_accuracy: 0.6500 - val_loss: 0.9603
# Epoch 923/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7500 - loss: 0.6876 - val_accuracy: 0.5500 - val_loss: 0.9497
# Epoch 924/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8000 - loss: 0.6179 - val_accuracy: 0.6000 - val_loss: 0.8949
# Epoch 925/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7750 - loss: 0.6825 - val_accuracy: 0.5500 - val_loss: 0.9782
# Epoch 926/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8500 - loss: 0.5754 - val_accuracy: 0.6500 - val_loss: 0.8702
# Epoch 927/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9000 - loss: 0.5018 - val_accuracy: 0.6000 - val_loss: 0.9026
# Epoch 928/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7750 - loss: 0.6972 - val_accuracy: 0.6500 - val_loss: 0.8993
# Epoch 929/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6750 - loss: 0.7583 - val_accuracy: 0.6000 - val_loss: 0.9241
# Epoch 930/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7500 - loss: 0.6276 - val_accuracy: 0.6000 - val_loss: 0.9407
# Epoch 931/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8500 - loss: 0.5553 - val_accuracy: 0.6500 - val_loss: 0.8738
# Epoch 932/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7000 - loss: 0.6894 - val_accuracy: 0.7000 - val_loss: 0.8357
# Epoch 933/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7750 - loss: 0.6571 - val_accuracy: 0.6000 - val_loss: 0.8621
# Epoch 934/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6750 - loss: 0.7231 - val_accuracy: 0.7000 - val_loss: 0.8193
# Epoch 935/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8000 - loss: 0.6137 - val_accuracy: 0.7000 - val_loss: 0.8332
# Epoch 936/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8250 - loss: 0.5304 - val_accuracy: 0.7000 - val_loss: 0.7481
# Epoch 937/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8250 - loss: 0.5136 - val_accuracy: 0.7000 - val_loss: 0.7534
# Epoch 938/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8500 - loss: 0.6122 - val_accuracy: 0.6000 - val_loss: 0.8480
# Epoch 939/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7250 - loss: 0.8038 - val_accuracy: 0.6000 - val_loss: 0.9158
# Epoch 940/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6250 - loss: 0.8639 - val_accuracy: 0.6500 - val_loss: 0.8219
# Epoch 941/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.7500 - loss: 0.7656 - val_accuracy: 0.7000 - val_loss: 0.8450
# Epoch 942/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7250 - loss: 0.6669 - val_accuracy: 0.6500 - val_loss: 0.7835
# Epoch 943/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7750 - loss: 0.7672 - val_accuracy: 0.6500 - val_loss: 0.8089
# Epoch 944/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6750 - loss: 0.8032 - val_accuracy: 0.7000 - val_loss: 0.8208
# Epoch 945/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7250 - loss: 0.6315 - val_accuracy: 0.6500 - val_loss: 0.7384
# Epoch 946/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8250 - loss: 0.5845 - val_accuracy: 0.6500 - val_loss: 0.8028
# Epoch 947/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8250 - loss: 0.5072 - val_accuracy: 0.7000 - val_loss: 0.7368
# Epoch 948/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7250 - loss: 0.7814 - val_accuracy: 0.7000 - val_loss: 0.8056
# Epoch 949/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7500 - loss: 0.6479 - val_accuracy: 0.6500 - val_loss: 0.8874
# Epoch 950/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7250 - loss: 0.6436 - val_accuracy: 0.6500 - val_loss: 0.8227
# Epoch 951/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7500 - loss: 0.6738 - val_accuracy: 0.7000 - val_loss: 0.8056
# Epoch 952/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9000 - loss: 0.5363 - val_accuracy: 0.6500 - val_loss: 0.7905
# Epoch 953/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8250 - loss: 0.5017 - val_accuracy: 0.8000 - val_loss: 0.7827
# Epoch 954/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7750 - loss: 0.6672 - val_accuracy: 0.7000 - val_loss: 0.6966
# Epoch 955/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8750 - loss: 0.4703 - val_accuracy: 0.6500 - val_loss: 0.7529
# Epoch 956/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7250 - loss: 0.7340 - val_accuracy: 0.6500 - val_loss: 0.7297
# Epoch 957/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7750 - loss: 0.6575 - val_accuracy: 0.6500 - val_loss: 0.8471
# Epoch 958/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8000 - loss: 0.6389 - val_accuracy: 0.6000 - val_loss: 0.8936
# Epoch 959/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8000 - loss: 0.5454 - val_accuracy: 0.6500 - val_loss: 0.7182
# Epoch 960/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8000 - loss: 0.6001 - val_accuracy: 0.7000 - val_loss: 0.7553
# Epoch 961/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8000 - loss: 0.7741 - val_accuracy: 0.6500 - val_loss: 0.8433
# Epoch 962/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.7750 - loss: 0.6101 - val_accuracy: 0.7500 - val_loss: 0.7751
# Epoch 963/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8250 - loss: 0.7928 - val_accuracy: 0.7000 - val_loss: 0.7819
# Epoch 964/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8000 - loss: 0.5218 - val_accuracy: 0.7000 - val_loss: 0.8067
# Epoch 965/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8500 - loss: 0.4018 - val_accuracy: 0.7000 - val_loss: 0.8297
# Epoch 966/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7000 - loss: 0.6778 - val_accuracy: 0.7000 - val_loss: 0.7960
# Epoch 967/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8000 - loss: 0.6588 - val_accuracy: 0.6500 - val_loss: 0.8344
# Epoch 968/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8000 - loss: 0.5669 - val_accuracy: 0.6500 - val_loss: 0.7833
# Epoch 969/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7250 - loss: 0.6569 - val_accuracy: 0.6500 - val_loss: 0.9335
# Epoch 970/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7250 - loss: 0.7448 - val_accuracy: 0.6500 - val_loss: 0.9314
# Epoch 971/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8500 - loss: 0.5799 - val_accuracy: 0.6500 - val_loss: 0.7739
# Epoch 972/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8000 - loss: 0.5608 - val_accuracy: 0.6500 - val_loss: 0.8843
# Epoch 973/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8250 - loss: 0.5945 - val_accuracy: 0.7000 - val_loss: 0.8172
# Epoch 974/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8500 - loss: 0.5712 - val_accuracy: 0.6500 - val_loss: 0.8082
# Epoch 975/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7000 - loss: 0.6635 - val_accuracy: 0.6500 - val_loss: 0.8476
# Epoch 976/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8000 - loss: 0.6564 - val_accuracy: 0.6500 - val_loss: 0.9103
# Epoch 977/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8500 - loss: 0.5365 - val_accuracy: 0.6500 - val_loss: 0.7668
# Epoch 978/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8250 - loss: 0.6195 - val_accuracy: 0.6500 - val_loss: 0.8602
# Epoch 979/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6750 - loss: 0.6026 - val_accuracy: 0.7000 - val_loss: 0.8372
# Epoch 980/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8750 - loss: 0.5755 - val_accuracy: 0.7000 - val_loss: 0.7102
# Epoch 981/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.7500 - loss: 0.5709 - val_accuracy: 0.7000 - val_loss: 0.7359
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8250 - loss: 0.5928 - val_accuracy: 0.6500 - val_loss: 0.7994
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8750 - loss: 0.5781 - val_accuracy: 0.6500 - val_loss: 0.8141
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8500 - loss: 0.4820 - val_accuracy: 0.7000 - val_loss: 0.7455
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7500 - loss: 0.6602 - val_accuracy: 0.6500 - val_loss: 0.8857
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8000 - loss: 0.5871 - val_accuracy: 0.7000 - val_loss: 0.8436
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8500 - loss: 0.5683 - val_accuracy: 0.6500 - val_loss: 0.8124
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8500 - loss: 0.5152 - val_accuracy: 0.6500 - val_loss: 0.8697
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7000 - loss: 0.6804 - val_accuracy: 0.6500 - val_loss: 0.8145
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8500 - loss: 0.5538 - val_accuracy: 0.7000 - val_loss: 0.7978
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8750 - loss: 0.6242 - val_accuracy: 0.6500 - val_loss: 0.8250
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7750 - loss: 0.5618 - val_accuracy: 0.7000 - val_loss: 0.7661
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8500 - loss: 0.5137 - val_accuracy: 0.6500 - val_loss: 0.8207
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8000 - loss: 0.6043 - val_accuracy: 0.7000 - val_loss: 0.7799
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7750 - loss: 0.5690 - val_accuracy: 0.6000 - val_loss: 0.8824
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9250 - loss: 0.4444 - val_accuracy: 0.7500 - val_loss: 0.7575
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8250 - loss: 0.6601 - val_accuracy: 0.7500 - val_loss: 0.8126
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8500 - loss: 0.5550 - val_accuracy: 0.7000 - val_loss: 0.7517
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8250 - loss: 0.5479 - val_accuracy: 0.6500 - val_loss: 0.7763
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8750 - loss: 0.4867 - val_accuracy: 0.6500 - val_loss: 0.8099

# %% [markdown]
# Let's plot the loss:

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# And now let's plot the accuracy:

# %%
print(cnnhistory.history.keys())
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')                                                                                                                                                                   
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# # Save the model

# %%
model_name = 'Emotion_Voice_Detection_Model.h5'
save_dir = './models'
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved trained model at ./models\Emotion_Voice_Detection_Model.h5

# %% [markdown]
# # Reloading the model to test it

# %%
loaded_model = keras.models.load_model('./models/Emotion_Voice_Detection_Model.h5')
loaded_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 40, 128)        │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 5, 128)         │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         6,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,228 (348.55 KB)
#  Trainable params: 89,226 (348.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# # Checking the accuracy of the loaded model

# %%
loss, acc = loaded_model.evaluate(x_testcnn, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step - accuracy: 0.6500 - loss: 0.8099
# Restored model, accuracy: 65.00%

# %% [markdown]
# # Thank you for your attention! To be continued..
